# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# ### Project
#
# # Bike store sales
#
# Let's put in practice the topics covered in the course and analyze sales made in a Bike Shop.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('sales_data.csv')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### First look at our data
#
# Analyze what columns we have, what type they are and what data is on them.

# %%
sales.shape
# Out:
# (5000, 16)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              5000 non-null   object
#  1   Day               5000 non-null   int64
#  2   Month             5000 non-null   object
#  3   Year              5000 non-null   int64
#  4   Customer_Age      5000 non-null   int64
#  5   Customer_Gender   5000 non-null   object
#  6   Country           5000 non-null   object
#  7   State             5000 non-null   object
#  8   Product_Category  5000 non-null   object
#  9   Sub_Category      5000 non-null   object
#  10  Product           5000 non-null   object
#  11  Order_Quantity    5000 non-null   int64
#  12  Unit_Cost         5000 non-null   int64
#  13  Unit_Price        5000 non-null   int64
#  14  Profit            5000 non-null   int64
#  15  Revenue           5000 non-null   int64
# dtypes: int64(8), object(8)
# memory usage: 625.1+ KB

# %%
sales.head()
# Out:
#          Date  Day      Month  Year  Customer_Age Customer_Gender  \
# 0  2014-03-05    5      March  2014            34               M
# 1  2013-08-18   18     August  2013            31               F
# 2  2014-02-04    4   February  2014            31               F
# 3  2013-09-09    9  September  2013            33               M
# 4  2016-05-16   16        May  2016            35               F
#
#          Country             State Product_Category     Sub_Category  \
# 0  United States        California      Accessories          Fenders
# 1         Canada  British Columbia         Clothing            Vests
# 2  United States        Washington            Bikes    Touring Bikes
# 3      Australia          Victoria      Accessories  Tires and Tubes
# 4  United States        Washington      Accessories  Tires and Tubes
#
#                    Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 0    Fender Set - Mountain              27          8          22     366
# 1          Classic Vest, L              13         24          64     512
# 2  Touring-1000 Yellow, 54               1       1482        2384     378
# 3             LL Road Tire              25          8          21     215
# 4       Mountain Tire Tube              28          2           5      53
#
#    Revenue
# 0      582
# 1      824
# 2     1860
# 3      415
# 4      109

# %%
sales.tail()
# Out:
#             Date  Day     Month  Year  Customer_Age Customer_Gender  \
# 4995  2014-01-27   27   January  2014            34               M
# 4996  2014-07-14   14      July  2014            17               M
# 4997  2013-12-30   30  December  2013            25               F
# 4998  2016-01-06    6   January  2016            57               M
# 4999  2014-03-09    9     March  2014            50               F
#
#             Country             State Product_Category       Sub_Category  \
# 4995  United States        California      Accessories  Bottles and Cages
# 4996         France        Val d'Oise         Clothing               Caps
# 4997         Canada  British Columbia      Accessories            Helmets
# 4998         Canada  British Columbia      Accessories    Tires and Tubes
# 4999      Australia        Queensland      Accessories    Tires and Tubes
#
#                      Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 4995   Water Bottle - 30 oz.              20          2           5      58
# 4996            AWC Logo Cap              12          7           9       1
# 4997  Sport-100 Helmet, Blue              20         13          35     433
# 4998     Patch Kit/8 Patches              16          1           2      16
# 4999     Patch Kit/8 Patches              15          1           2      10
#
#       Revenue
# 4995       98
# 4996       85
# 4997      693
# 4998       32
# 4999       25

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Fixing column types
#
# - Cast `Date` to `datetime`.
# - Cast `Customer_Gender`, `Country`, `State`, `Product_Category` and `Sub_Category` to `category`.

# %%
# your code goes here
sales['Date'] = pd.to_datetime(sales['Date'])
sales['Customer_Gender'] = sales['Customer_Gender'].astype("category")
sales['Country'] = sales['Country'].astype("category")
sales['State'] = sales['State'].astype("category")
sales['Product_Category'] = sales['Product_Category'].astype("category")
sales['Sub_Category'] = sales['Sub_Category'].astype("category")

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get a summary of the main statistics of the whole data

# %%
# your code goes here
sales.describe()
# Out:
#                              Date          Day         Year  Customer_Age  \
# count                        5000  5000.000000  5000.000000   5000.000000
# mean   2014-11-24 09:47:13.920000    15.668800  2014.405000     35.933800
# min           2011-01-03 00:00:00     1.000000  2011.000000     17.000000
# 25%           2013-12-27 00:00:00     8.000000  2013.000000     28.000000
# 50%           2014-07-02 12:00:00    16.000000  2014.000000     35.000000
# 75%           2016-01-07 00:00:00    23.000000  2016.000000     43.000000
# max           2016-07-31 00:00:00    31.000000  2016.000000     87.000000
# std                           NaN     8.797783     1.266055     11.087886
#
#        Order_Quantity    Unit_Cost   Unit_Price       Profit       Revenue
# count     5000.000000  5000.000000  5000.000000  5000.000000   5000.000000
# mean        11.820400   278.415000   470.680600   291.653400    772.758000
# min          1.000000     1.000000     2.000000   -24.000000      2.000000
# 25%          2.000000     2.000000     5.000000    29.000000     64.000000
# 50%         10.000000     9.000000    25.000000   103.000000    226.000000
# 75%         20.000000    42.000000    70.000000   367.000000    829.250000
# max         32.000000  2171.000000  3578.000000  5342.000000  14026.000000
# std          9.607841   562.721951   941.590529   457.359971   1306.052588

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales["Customer_Age"].mean()
# Out:
# 35.9338

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales["Customer_Age"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
sales["Customer_Age"].plot(kind = "box")
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales["Order_Quantity"].mean()
# Out:
# 11.8204

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales["Order_Quantity"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales["Order_Quantity"].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### In which countries were sales made?

# %%
# your code goes here
sales["Country"].unique()
# Out:
# ['United States', 'Canada', 'Australia', 'United Kingdom', 'Germany', 'France']
# Categories (6, object): ['Australia', 'Canada', 'France', 'Germany', 'United Kingdom',
#                          'United States']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Sort sales by year
#
# Older sales should be at the bottom.

# %%
# your code goes here
sales.sort_values(['Year',"Month","Day"],ascending = False, inplace = True)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Reset the current index
#
# Don't keep the old index.

# %%
# your code goes here
sales.reset_index(drop = True, inplace = True)
sales
# Out:
#            Date  Day  Month  Year  Customer_Age Customer_Gender  \
# 0    2016-05-31   31    May  2016            29               M
# 1    2016-05-31   31    May  2016            40               F
# 2    2016-05-30   30    May  2016            25               M
# 3    2016-05-30   30    May  2016            45               F
# 4    2016-05-30   30    May  2016            29               M
# ...         ...  ...    ...   ...           ...             ...
# 4995 2011-04-12   12  April  2011            37               F
# 4996 2011-04-11   11  April  2011            42               F
# 4997 2011-04-07    7  April  2011            40               M
# 4998 2011-04-06    6  April  2011            18               M
# 4999 2011-04-03    3  April  2011            17               F
#
#             Country             State Product_Category     Sub_Category  \
# 0     United States        Washington      Accessories  Hydration Packs
# 1           Germany          Saarland      Accessories  Tires and Tubes
# 2     United States        Washington      Accessories  Tires and Tubes
# 3     United States        California      Accessories         Cleaners
# 4         Australia          Victoria      Accessories  Tires and Tubes
# ...             ...               ...              ...              ...
# 4995         Canada  British Columbia            Bikes       Road Bikes
# 4996        Germany          Saarland            Bikes   Mountain Bikes
# 4997  United States        Washington            Bikes       Road Bikes
# 4998         Canada  British Columbia            Bikes       Road Bikes
# 4999      Australia          Victoria            Bikes       Road Bikes
#
#                       Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 0     Hydration Pack - 70 oz.              19         21          55     416
# 1          Mountain Tire Tube               8          2           5      17
# 2           Touring Tire Tube              22          2           5      42
# 3       Bike Wash - Dissolver              18          3           8      87
# 4          Mountain Tire Tube              27          2           5      53
# ...                       ...             ...        ...         ...     ...
# 4995       Road-650 Black, 60               1        487         783     288
# 4996  Mountain-200 Silver, 46               2       1266        2320    1273
# 4997       Road-650 Black, 48               1        487         783     124
# 4998         Road-150 Red, 48               1       2171        3578    1371
# 4999         Road-650 Red, 48               4        487         783     526
#
#       Revenue
# 0         815
# 1          33
# 2          86
# 3         141
# 4         107
# ...       ...
# 4995      775
# 4996     3805
# 4997      611
# 4998     3542
# 4999     2474
#
# [5000 rows x 16 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales.groupby('Year').size()
# Out:
# Year
# 2011     126
# 2012     112
# 2013    1040
# 2014    1327
# 2015    1123
# 2016    1272
# dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> and a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales.groupby('Year').size().plot(kind = 'pie')
# Out:
# <Axes: >

# %%
# your code goes here
sales.groupby('Year').size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a new `Cost` column
#
# This column should be:
# $$ Cost = Unit\_Cost * Order\_Quantity $$

# %%
# your code goes here
sales["Cost"]= sales["Unit_Cost"] * sales["Order_Quantity"]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a new `YearMonth` column
#
# This new `YearMonth` column should be the concatenation of `Year` and `Month` columns, separated by a '-'.

# %%
# your code goes here
sales['YearMonth'] = sales['Year'].astype(str) + '-' + sales['Month']
sales["YearMonth"] = pd.to_datetime(sales['YearMonth'], format='%Y-%B')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Count how many sales we have per `YearMonth`.

# %%
# your code goes here
sales.groupby("YearMonth").size()
# Out:
# YearMonth
# 2011-01-01      9
# 2011-02-01      6
# 2011-03-01     15
# 2011-04-01     12
# 2011-05-01     13
#              ...
# 2016-03-01    192
# 2016-04-01    218
# 2016-05-01    214
# 2016-06-01    211
# 2016-07-01     92
# Length: 62, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales.groupby("YearMonth").size().plot(kind = "bar")
# Out:
# <Axes: xlabel='YearMonth'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales.groupby("Country")["Order_Quantity"].size().idxmax()
# Out:
# <ipython-input-112-85f79996a188>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales.groupby("Country")["Order_Quantity"].size().idxmax()
# 'United States'

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales.groupby("Country")["Order_Quantity"].size().plot(kind="bar")
# Out:
# <ipython-input-113-ca0e97680823>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales.groupby("Country")["Order_Quantity"].size().plot(kind="bar")
# <Axes: xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get a list of every product sold

# %%
# your code goes here
sales["Product"].unique()
# Out:
# array(['Hydration Pack - 70 oz.', 'Mountain Tire Tube',
#        'Touring Tire Tube', 'Bike Wash - Dissolver',
#        'Sport-100 Helmet, Red', 'Mountain-500 Black, 42',
#        'Water Bottle - 30 oz.', 'Patch Kit/8 Patches',
#        'Sport-100 Helmet, Blue', 'Fender Set - Mountain', 'HL Road Tire',
#        'Mountain Bottle Cage', 'Sport-100 Helmet, Black',
#        'Half-Finger Gloves, S', 'Short-Sleeve Classic Jersey, S',
#        'HL Mountain Tire', 'ML Mountain Tire', 'Touring-1000 Yellow, 50',
#        'AWC Logo Cap', 'Road-350-W Yellow, 42', 'Touring-3000 Yellow, 44',
#        'Road Bottle Cage', 'Mountain-400-W Silver, 42',
#        'All-Purpose Bike Stand', 'Road-650 Red, 44',
#        'Mountain-200 Silver, 46', 'Touring-1000 Yellow, 60',
#        'Mountain-200 Black, 38', 'Touring-1000 Blue, 50',
#        'Racing Socks, L', 'Half-Finger Gloves, L',
#        'Long-Sleeve Logo Jersey, L', 'Touring-1000 Blue, 46',
#        'Short-Sleeve Classic Jersey, XL', 'Road-250 Black, 48',
#        'Road-250 Red, 48', 'Short-Sleeve Classic Jersey, L',
#        'LL Mountain Tire', 'ML Road Tire',
#        'Short-Sleeve Classic Jersey, M', 'Road Tire Tube',
#        'Long-Sleeve Logo Jersey, M', 'Road-650 Black, 48',
#        'Mountain-200 Black, 46', 'Road-750 Black, 48', 'LL Road Tire',
#        'Half-Finger Gloves, M', 'Long-Sleeve Logo Jersey, S',
#        'Road-150 Red, 52', 'Road-250 Red, 44', 'Touring Tire',
#        'Mountain-100 Black, 44', 'Mountain-100 Black, 48',
#        'Mountain-200 Silver, 38', 'Touring-1000 Yellow, 54',
#        "Women's Mountain Shorts, S", 'Touring-3000 Blue, 44',
#        'Road-650 Black, 60', 'Road-150 Red, 56', 'Road-350-W Yellow, 48',
#        'Touring-1000 Yellow, 46', 'Classic Vest, S',
#        'Mountain-200 Black, 42', 'Road-650 Black, 44', 'Road-250 Red, 58',
#        'Road-550-W Yellow, 42', 'Hitch Rack - 4-Bike',
#        'Mountain-200 Silver, 42', 'Classic Vest, L',
#        'Mountain-500 Black, 44', 'Touring-2000 Blue, 50',
#        'Road-550-W Yellow, 48', 'Touring-1000 Blue, 60',
#        'Racing Socks, M', "Women's Mountain Shorts, M",
#        'Road-750 Black, 52', 'Road-250 Black, 58', 'Road-750 Black, 58',
#        'Touring-3000 Blue, 62', 'Road-150 Red, 44', 'Road-750 Black, 44',
#        'Touring-3000 Yellow, 58', 'Mountain-100 Silver, 44',
#        'Mountain-400-W Silver, 40', 'Touring-3000 Yellow, 54',
#        'Touring-3000 Yellow, 50', 'Road-650 Red, 52',
#        'Road-250 Black, 52', 'Road-650 Red, 60',
#        'Mountain-400-W Silver, 46', 'Road-150 Red, 62',
#        'Road-550-W Yellow, 44', 'Road-550-W Yellow, 38',
#        'Touring-2000 Blue, 46', "Women's Mountain Shorts, L",
#        'Touring-3000 Blue, 54', 'Touring-2000 Blue, 60',
#        'Long-Sleeve Logo Jersey, XL', 'Classic Vest, M',
#        'Road-350-W Yellow, 40', 'Road-550-W Yellow, 40',
#        'Touring-1000 Blue, 54', 'Road-250 Black, 44',
#        'Touring-2000 Blue, 54', 'Mountain-500 Black, 52',
#        'Road-250 Red, 52', 'Mountain-100 Black, 38',
#        'Mountain-500 Silver, 40', 'Mountain-100 Silver, 38',
#        'Touring-3000 Yellow, 62', 'Mountain-400-W Silver, 38',
#        'Mountain-100 Silver, 48', 'Road-650 Red, 58', 'Road-650 Red, 48',
#        'Road-350-W Yellow, 44', 'Road-150 Red, 48', 'Road-650 Red, 62',
#        'Mountain-500 Black, 48', 'Road-650 Black, 58',
#        'Road-650 Black, 62', 'Mountain-500 Black, 40',
#        'Mountain-100 Black, 42', 'Mountain-500 Silver, 44',
#        'Touring-3000 Blue, 58', 'Road-650 Black, 52',
#        'Mountain-500 Silver, 52', 'Mountain-500 Silver, 42',
#        'Touring-3000 Blue, 50', 'Mountain-500 Silver, 48',
#        'Mountain-100 Silver, 42'], dtype=object)

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
(sales.groupby("Product")["Order_Quantity"].sum()).sort_values(ascending=False).head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind = "scatter",x = "Unit_Cost",y= "Unit_Price")
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind = "scatter", x = "Order_Quantity", y = "Profit")
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales.boxplot(column = "Profit", by = "Country")
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales.boxplot(column = "Customer_Age", by = "Country")
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales["Revenue"] +=  50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
sales[sales["Country"].isin(["Canada","France"])].shape[0]
# Out:
# 1146

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales[(sales["Country"] == "Canada")&(sales["Sub_Category"]=="Bike Racks")].shape[0]
# Out:
# 3

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
x= sales[sales["Country"] == "France"]["State"].value_counts()
x= x[~(x==0)]

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
x.plot(kind = "bar")
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales.groupby("Product_Category").size()
# Out:
# <ipython-input-174-67601d7c3500>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales.groupby("Product_Category").size()
# Product_Category
# Accessories    3090
# Bikes          1166
# Clothing        744
# dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales.groupby("Product_Category").size().plot(kind = "pie")
# Out:
# <ipython-input-175-f33ffed5517b>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales.groupby("Product_Category").size().plot(kind = "pie")
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
y = sales[sales['Product_Category'] == "Accessories"].groupby("Sub_Category").size()
y = y[~(y==0)]
# Out:
# <ipython-input-182-037202a03cb2>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   y = sales[sales['Product_Category'] == "Accessories"].groupby("Sub_Category").size()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
y.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
z = sales[sales["Product_Category"] == "Bikes"].groupby("Sub_Category").size()
z = z[z!=0]
# Out:
# <ipython-input-184-f02c4f3cca02>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   z = sales[sales["Product_Category"] == "Bikes"].groupby("Sub_Category").size()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
z.plot(kind = "pie")
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales.groupby("Customer_Gender").size().idxmax()
# Out:
# <ipython-input-190-d15c63b04ec4>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales.groupby("Customer_Gender").size().idxmax()
# 'M'

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
sales[(sales["Customer_Gender"] == "M")&(sales["Revenue"]>500)].shape[0]
# Out:
# 1058

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sales.sort_values(["Revenue"], ascending = False).head(5)
# Out:
#            Date  Day     Month  Year  Customer_Age Customer_Gender  \
# 4953 2011-01-17   17   January  2011            44               F
# 4916 2011-03-27   27     March  2011            24               M
# 729  2016-01-28   28   January  2016            34               M
# 4964 2011-12-29   29  December  2011            25               M
# 2162 2015-12-11   11  December  2015            44               M
#
#             Country             State Product_Category Sub_Category  \
# 4953  United States        California            Bikes   Road Bikes
# 4916  United States        California            Bikes   Road Bikes
# 729          Canada  British Columbia            Bikes   Road Bikes
# 4964         Canada  British Columbia            Bikes   Road Bikes
# 2162         Canada  British Columbia            Bikes   Road Bikes
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 4953  Road-150 Red, 62               4       2171        3578    5342
# 4916  Road-150 Red, 44               4       2171        3578    5342
# 729   Road-150 Red, 62               3       2171        3578    4114
# 4964  Road-150 Red, 62               3       2171        3578    4114
# 2162  Road-150 Red, 62               3       2171        3578    4114
#
#       Revenue  Cost  YearMonth
# 4953    14076  8684 2011-01-01
# 4916    14076  8684 2011-03-01
# 729     10677  6513 2016-01-01
# 4964    10677  6513 2011-12-01
# 2162    10677  6513 2015-12-01

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
sales.sort_values(["Revenue"], ascending = False).head(1)
# Out:
#            Date  Day    Month  Year  Customer_Age Customer_Gender  \
# 4953 2011-01-17   17  January  2011            44               F
#
#             Country       State Product_Category Sub_Category  \
# 4953  United States  California            Bikes   Road Bikes
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 4953  Road-150 Red, 62               4       2171        3578    5342
#
#       Revenue  Cost  YearMonth
# 4953    14076  8684 2011-01-01

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
sales[sales["Revenue"] >10000]["Order_Quantity"].mean()
# Out:
# 3.25

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
sales[sales["Revenue"] <10000]["Order_Quantity"].mean()
# Out:
# 11.834134615384615

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
sales[(sales["Month"] == "May")&(sales["Year"]== 2016)].shape[0]
# Out:
# 214

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
f= sales[(sales['Date'] >= '2016-05-01') & (sales['Date'] <= '2016-07-31')]
f.shape[0]
# Out:
# 517

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
f.boxplot(column = "Profit",by= "Month")
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='Month'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
sales[sales["Country"] == "United States"]["Unit_Price"] *= 1.072
# Out:
# <ipython-input-219-8aeb14c7318b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales[sales["Country"] == "United States"]["Unit_Price"] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
sales.head()
# Out:
#         Date  Day Month  Year  Customer_Age Customer_Gender        Country  \
# 0 2016-05-31   31   May  2016            29               M  United States
# 1 2016-05-31   31   May  2016            40               F        Germany
# 2 2016-05-30   30   May  2016            25               M  United States
# 3 2016-05-30   30   May  2016            45               F  United States
# 4 2016-05-30   30   May  2016            29               M      Australia
#
#         State Product_Category     Sub_Category                  Product  \
# 0  Washington      Accessories  Hydration Packs  Hydration Pack - 70 oz.
# 1    Saarland      Accessories  Tires and Tubes       Mountain Tire Tube
# 2  Washington      Accessories  Tires and Tubes        Touring Tire Tube
# 3  California      Accessories         Cleaners    Bike Wash - Dissolver
# 4    Victoria      Accessories  Tires and Tubes       Mountain Tire Tube
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Revenue  Cost  YearMonth
# 0              19         21          55     416      865   399 2016-05-01
# 1               8          2           5      17       83    16 2016-05-01
# 2              22          2           5      42      136    44 2016-05-01
# 3              18          3           8      87      191    54 2016-05-01
# 4              27          2           5      53      157    54 2016-05-01
